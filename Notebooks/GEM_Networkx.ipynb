# %% [markdown]
# # set data dir

# %%
import sys
import os

# path = "C:/Users/meide/Documents/GitHub/Master/data"
path = "data/"
os.chdir(path)

# %%
import pandas as pd

df = pd.read_csv("PyvisData_BiGG_MNXM.csv")

# %%
mass_molLogP =  [(1.00794,0.1125),
(1.00794,0.1125),
(663.11022,-3.466129999999994),
(170.99461,-4.447399999999999),
(805.09667,-3.2941999999999974),
(255.99952,-4.160199999999997),
(862.09487,-4.783999999999996),
(180.06339,-3.2213999999999987),
(132.00697,-3.7628),
(189.00517,-5.252599999999999),
(261.93016,-4.435499999999998),
(46.04186,-0.0014),
(43.98983,-0.5835),
(228.0046,-3.885099999999998),
(228.0046,-3.885099999999998),
(728.57436,15.017619999999964),
(144.00697,-3.1644999999999994),
(87.00877,-1.6747),
(726.55871,14.40089999999997),
(116.01206,-2.733599999999999),
(197.99404,-3.2476),
(59.01385,-1.2438),
(182.97111,-4.057499999999999),
(137.97291,-1.6218),
(502.96664,-4.156999999999997),
(146.06914,-0.2862299999999998),
(44.9982,-1.6339),
(424.00759,-3.6419999999999977),
(129.99132,-3.5546),
(740.05362,-5.208129999999997),
(72.99312,-2.0648),
(763.0861,-3.644099999999999),
(182.97111,-4.057499999999999),
(345.04853,-3.126999999999998),
(18.03383,0.3762),
(180.06339,-3.219799999999999),
(164.96055,-2.904699999999999),
(95.96234,-2.1926),
(89.02442,-1.8829),
(288.02573,-5.163299999999996),
(273.0028,-5.974799999999997),
(46.04186,-0.0014),
(31.98983,0.067),
(31.98983,0.067),
(44.02621,0.2052),
(113.99641,-2.9576),
(741.062,-4.61313),
(167.98347,-2.608499999999999),
(146.04588,-2.071599999999999),
(44.02621,0.2052),
(167.98347,-2.606899999999999),
(662.10185,-4.061129999999994),
(189.00517,-5.396699999999999),
(95.96234,-2.1926),
(18.01056,-0.8247)]

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

net2 = nx.DiGraph()

# set the physics layout of the network
data = pd.read_csv("Chemical_descriptors_e_coli_core_ranked_targets.csv")

sources = data["BiGG"]
targets = data['target']
coordinates = data[['mass','MolLogP']]

edge_data = zip(sources, coordinates,targets)

for e in edge_data:
    src = e[0]
    c = e[1]
    tar = e[2]
   

    net2.add_node(src, pos = c)
    net2.add_node(tar, pos = c)
    # net2.add_edge(tar, src)
   

#blue_edges = [("pep", "pyr")]
#red_edges = [('pyr', 'accoa'),("accoa","cit"),("akg","succoa"),("succoa","succ")]
#Green_edges = [('accoa', 'cit')]

#edge_colours = ['black' if not edge in red_edges else 'tab:red'
                    #for edge in net2.edges()]

#black_edges = [edge for edge in net2.edges() if edge not in red_edges]

# blue_edges = [edge for edge in net2.edges() if edge not in red_edges and black_edges]





pos=nx.get_node_attributes(net2,'pos')
fig, ax = plt.subplots(figsize=(50,40))

nx.draw(net2, pos , with_labels = True, arrows = True, ax = ax)

#nx.draw_networkx_nodes(net2, pos, cmap=plt.get_cmap('jet'),node_color = "b", node_size = 500, ) 
#nx.draw_networkx_labels(net2, pos,font_size = 12, font_color="black")
#nx.draw_networkx_edges(net2, pos, edgelist=red_edges,  width=8, alpha=0.5, edge_color="tab:red", arrows = True)
#nx.draw_networkx_edges(net2, pos, edgelist=black_edges, arrows=True)
#nx.draw_networkx_edges(net2, pos, edgelist=blue_edges, arrows=True)
limits=plt.axis('on') # turns on axis
ax.set_xlabel("ExactMolWt")
ax.set_ylabel("MolLogP")
ax.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10788/983171710.py in <module>
#      43 fig, ax = plt.subplots(figsize=(50,40))
#      44
# ---> 45 nx.draw(net2, pos , with_labels = True, arrows = True, ax = ax)
#      46
#      47 #nx.draw_networkx_nodes(net2, pos, cmap=plt.get_cmap('jet'),node_color = "b", node_size = 500, )
#
# ~\.conda\envs\rdkit\lib\site-packages\networkx\drawing\nx_pylab.py in draw(G, pos, ax, **kwds)
#     119         kwds["with_labels"] = "labels" in kwds
#     120
# --> 121     draw_networkx(G, pos=pos, ax=ax, **kwds)
#     122     ax.set_axis_off()
#     123     plt.draw_if_interactive()
#
# ~\.conda\envs\rdkit\lib\site-packages\networkx\drawing\nx_pylab.py in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     331         pos = nx.drawing.spring_layout(G)  # default to spring layout
#     332
# --> 333     draw_networkx_nodes(G, pos, **node_kwds)
#     334     draw_networkx_edges(G, pos, arrows=arrows, **edge_kwds)
#     335     if with_labels:
#
# ~\.conda\envs\rdkit\lib\site-packages\networkx\drawing\nx_pylab.py in draw_networkx_nodes(G, pos, nodelist, node_size, node_color, node_shape, alpha, cmap, vmin, vmax, ax, linewidths, edgecolors, label, margins)
#     461
#     462     node_collection = ax.scatter(
# --> 463         xy[:, 0],
#     464         xy[:, 1],
#     465         s=node_size,
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

net2 = nx.DiGraph()

# set the physics layout of the network
data = pd.read_csv("PyvisData_BiGG_MNXM.csv")

sources = data["BiGG"]
targets = data['target']
coordinates = MolLogP_NumHDonor

edge_data = zip(sources, coordinates)

for e in edge_data:
    src = e[0]
    c = e[1]
   

    net2.add_node(src, pos = c)
    # net2.add_node(dst, pos = c)
   

blue_edges = [("pep", "pyr")]
red_edges = [('pyr', 'accoa'),("accoa","cit"),("akg","succoa"),("succoa","succ")]
Green_edges = [('accoa', 'cit')]

edge_colours = ['black' if not edge in red_edges else 'tab:red'
                    for edge in net2.edges()]

black_edges = [edge for edge in net2.edges() if edge not in red_edges]

blue_edges = [edge for edge in net2.edges() if edge not in red_edges and black_edges]





pos=nx.get_node_attributes(net2,'pos')
fig, ax = plt.subplots(figsize=(50,40))

nx.draw(net2,pos, with_labels = False, arrows = True, ax = ax)

#nx.draw_networkx_nodes(net2, pos, cmap=plt.get_cmap('jet'),node_color = "b", node_size = 500, ) 
#nx.draw_networkx_labels(net2, pos,font_size = 12, font_color="black")
#nx.draw_networkx_edges(net2, pos, edgelist=red_edges,  width=8, alpha=0.5, edge_color="tab:red", arrows = True)
#nx.draw_networkx_edges(net2, pos, edgelist=black_edges, arrows=True)
#nx.draw_networkx_edges(net2, pos, edgelist=blue_edges, arrows=True)
limits=plt.axis('on') # turns on axis
ax.set_xlabel("ExactMolWt")
ax.set_ylabel("MolLogP")
ax.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True)

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

net2 = nx.DiGraph()

# set the physics layout of the network
data = pd.read_csv("Metabolic_network_targets.csv")

sources = data["BiGG"]
targets = data['target']
coordinates = mass_charge


edge_data = zip(sources, targets, coordinates)

for e in edge_data:
    src = e[0]
    dst = e[1]
    c = e[2]

    net2.add_node(src, pos = c)
    net2.add_node(dst, pos = c)
    net2.add_edge(src, dst)


pos=nx.get_node_attributes(net2,'pos')
fig, ax = plt.subplots(figsize=(10,10))

net2.remove_edges_from(nx.selfloop_edges(net2))

nx.draw(net2,pos, with_labels = False, node_size = 10, arrows = True, ax = ax)

#nx.draw_networkx_nodes(net2, pos, cmap=plt.get_cmap('jet'),node_color = "b", node_size = 500, ) 
#nx.draw_networkx_labels(net2, pos,font_size = 12, font_color="black")
#nx.draw_networkx_edges(net2, pos, edgelist=red_edges,  width=8, alpha=0.5, edge_color="tab:red", arrows = True)
#nx.draw_networkx_edges(net2, pos, edgelist=black_edges, arrows=True)
#nx.draw_networkx_edges(net2, pos, edgelist=blue_edges, arrows=True)
limits=plt.axis('on') # turns on axis
ax.set_xlabel("mass")
ax.set_ylabel("charge")
ax.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True)

# %%
nx.info(net2)
# Out:
# 'DiGraph with 512 nodes and 722 edges'

# %%
nx.degree_histogram(net2)

# %%
mass_molLogP =  [(1.00794,0.1125),
(1.00794,0.1125),
(663.11022,-3.466129999999994),
(170.99461,-4.447399999999999),
(805.09667,-3.2941999999999974),
(255.99952,-4.160199999999997),
(862.09487,-4.783999999999996),
(180.06339,-3.2213999999999987),
(132.00697,-3.7628),
(189.00517,-5.252599999999999),
(261.93016,-4.435499999999998),
(46.04186,-0.0014),
(43.98983,-0.5835),
(228.0046,-3.885099999999998),
(228.0046,-3.885099999999998),
(728.57436,15.017619999999964),
(144.00697,-3.1644999999999994),
(87.00877,-1.6747),
(726.55871,14.40089999999997),
(116.01206,-2.733599999999999),
(197.99404,-3.2476),
(59.01385,-1.2438),
(182.97111,-4.057499999999999),
(137.97291,-1.6218),
(502.96664,-4.156999999999997),
(146.06914,-0.2862299999999998),
(44.9982,-1.6339),
(424.00759,-3.6419999999999977),
(129.99132,-3.5546),
(740.05362,-5.208129999999997),
(72.99312,-2.0648),
(763.0861,-3.644099999999999),
(182.97111,-4.057499999999999),
(345.04853,-3.126999999999998),
(18.03383,0.3762),
(180.06339,-3.219799999999999),
(164.96055,-2.904699999999999),
(95.96234,-2.1926),
(89.02442,-1.8829),
(288.02573,-5.163299999999996),
(273.0028,-5.974799999999997),
(46.04186,-0.0014),
(31.98983,0.067),
(31.98983,0.067),
(44.02621,0.2052),
(113.99641,-2.9576),
(741.062,-4.61313),
(167.98347,-2.608499999999999),
(146.04588,-2.071599999999999),
(44.02621,0.2052),
(167.98347,-2.606899999999999),
(662.10185,-4.061129999999994),
(189.00517,-5.396699999999999),
(95.96234,-2.1926),
(18.01056,-0.8247)]

# %%
label_core = {}
label_core[1] = "M_h_c"
label_core[2] = "M_h_c"
label_core[3] = "M_nadh_c"
label_core[4] = "M_acon_C_c"
label_core[5] = "M_accoa_c"
label_core[6] = "M_6pgl_c"
label_core[7] = "M_succoa_c"
label_core[8] = "M_glc__D_e"
label_core[9] = "M_mal__L_c"
label_core[10] = "M_cit_c"
label_core[11] = "M_13dpg_c"
label_core[12] = "M_etoh_c"
label_core[13] = "M_co2_c"
label_core[14] = "M_ru5p__D_c"
label_core[15] = "M_xu5p__D_c"
label_core[16] = "M_q8h2_c"
label_core[17] = "M_akg_e"
label_core[18] = "M_pyr_c"
label_core[19] = "M_q8_c"
label_core[20] = "M_succ_c"
label_core[21] = "M_e4p_c"
label_core[22] = "M_ac_c"
label_core[23] = "M_2pg_c"
label_core[24] = "M_actp_c"
label_core[25] = "M_atp_c"
label_core[26] = "M_gln__L_c"
label_core[27] = "M_for_c"
label_core[28] = "M_adp_c"
label_core[29] = "M_oaa_c"
label_core[30] = "M_nadp_c"
label_core[31] = "M_glx_c"
label_core[32] = "M_coa_c"
label_core[33] = "M_3pg_c"
label_core[34] = "M_amp_c"
label_core[35] = "M_nh4_c"
label_core[36] = "M_fru_e"
label_core[37] = "M_pep_c"
label_core[38] = "M_pi_c"
label_core[39] = "M_lac__D_c"
label_core[40] = "M_s7p_c"
label_core[41] = "M_6pgc_c"
label_core[42] = "M_etoh_e"
label_core[43] = "M_o2_c"
label_core[44] = "M_o2_e"
label_core[45] = "M_acald_c"
label_core[46] = "M_fuM_c"
label_core[47] = "M_nadph_c"
label_core[48] = "M_g3p_c"
label_core[49] = "M_glu__L_c"
label_core[50] = "M_acald_c"
label_core[51] = "M_dhap_c"
label_core[52] = "M_nad_c"
label_core[53] = "M_icit_c"
label_core[54] = "M_pi_c"
label_core[55] = "M_h2o_c"

# %%
print(labels)
# Out:
# {0: 'M_h_c', 1: 'M_h_c', 2: 'M_nadh_c', 3: 'M_acon_C_c', 4: 'M_accoa_c', 5: 'M_6pgl_c', 6: 'M_succoa_c', 7: 'M_glc__D_e', 8: 'M_mal__L_c', 9: 'M_cit_c', 10: 'M_13dpg_c', 11: 'M_etoh_c', 12: 'M_co2_c', 13: 'M_ru5p__D_c', 14: 'M_xu5p__D_c', 15: 'M_q8h2_c', 16: 'M_akg_e', 17: 'M_pyr_c', 18: 'M_q8_c', 19: 'M_succ_c', 20: 'M_e4p_c', 21: 'M_ac_c', 22: 'M_2pg_c', 23: 'M_actp_c', 24: 'M_atp_c', 25: 'M_gln__L_c', 26: 'M_for_c', 27: 'M_adp_c', 28: 'M_oaa_c', 29: 'M_nadp_c', 30: 'M_glx_c', 31: 'M_coa_c', 32: 'M_3pg_c', 33: 'M_amp_c', 34: 'M_nh4_c', 35: 'M_fru_e', 36: 'M_pep_c', 37: 'M_pi_c', 38: 'M_lac__D_c', 39: 'M_s7p_c', 40: 'M_6pgc_c', 41: 'M_etoh_e', 42: 'M_o2_c', 43: 'M_o2_e', 44: 'M_acald_c', 45: 'M_fuM_c', 46: 'M_nadph_c', 47: 'M_g3p_c', 48: 'M_glu__L_c', 49: 'M_acald_c', 50: 'M_dhap_c', 51: 'M_nad_c', 52: 'M_icit_c', 53: 'M_pi_c', 54: 'M_h2o_c'}

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

net2 = nx.DiGraph()


data = pd.read_csv("Chemical_descriptors_e_coli_core_ranked_targets.csv")

sources = data["target"]
targets = data['BiGG']
# coordinates = mass_molLogP
coordinates = data[["mass", "MolLogP"]].values

labels = label_core

edge_data = zip(sources, targets, coordinates)

for e in edge_data:
    src = e[0]
    dst = e[1]
    c = e[2]

    net2.add_node(src, pos = c)
    net2.add_node(dst, pos = c)
    net2.add_edge(src, dst)





pos=nx.get_node_attributes(net2,'pos')
fig, ax = plt.subplots(figsize=(30,30))
ax.set_xlabel("mass")
ax.set_ylabel("MolLogP")
limits=plt.axis('on') # turns on axis
ax.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True)
# net2.remove_edges_from(nx.selfloop_edges(net2))


nx.draw_networkx_nodes(net2,pos,)
nx.draw_networkx_edges(net2, pos, width=1.0, alpha=0.5)
nx.draw_networkx_labels(net2,pos, labels, font_size=10)


plt.tight_layout()
plt.axis("on")
plt.show()



#nx.draw(net2,pos,labels = labels, with_labels=True, node_size = 10, arrows = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10788/1213982628.py in <module>
#      41 nx.draw_networkx_nodes(net2,pos,)
#      42 nx.draw_networkx_edges(net2, pos, width=1.0, alpha=0.5)
# ---> 43 nx.draw_networkx_labels(net2,pos, labels, font_size=10)
#      44
#      45
#
# ~\.conda\envs\rdkit\lib\site-packages\networkx\drawing\nx_pylab.py in draw_networkx_labels(G, pos, labels, font_size, font_color, font_family, font_weight, alpha, bbox, horizontalalignment, verticalalignment, ax, clip_on)
#     972     text_items = {}  # there is no text collection so we'll fake one
#     973     for n, label in labels.items():
# --> 974         (x, y) = pos[n]
#     975         if not isinstance(label, str):
#     976             label = str(label)  # this makes "1" and 1 labeled the same
#
# KeyError: 1

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

net2 = nx.DiGraph()


data = pd.read_csv("Chemical_descriptors_e_coli_core_ranked_targets.csv")

sources = data["target"]
targets = data['BiGG']
# coordinates = mass_molLogP
coordinates = data[["mass", "MolLogP"]].values

labels = label_core

edge_data = zip(sources, targets, coordinates)

for e in edge_data:
    src = e[0]
    dst = e[1]
    c = e[2]

    net2.add_node(src, pos = c)
    net2.add_node(dst, pos = c)
    net2.add_edge(src, dst, pos = c)


pos=nx.get_node_attributes(net2,'pos')

# %%
print(pos)
# Out:
# {'M_13dpg_c': array([261.93016,  -4.4355 ]), 'M_3pg_c': array([95.96234, -2.1926 ]), 'M_atp_c': array([862.09487,  -4.784  ]), 'M_g3p_c': array([95.96234, -2.1926 ]), 'M_nad_c': array([862.09487,  -4.784  ]), 'M_pi_c': array([95.96234, -2.1926 ]), 'M_2pg_c': array([164.96055,  -2.9047 ]), 'M_6pgc_c': array([228.0046,  -3.8851]), 'M_6pgl_c': array([1.00794, 0.1125 ]), 'M_h2o_c': array([95.96234, -2.1926 ]), 'M_g6p_c': array([95.96234, -2.1926 ]), 'M_nadp_c': array([228.0046,  -3.8851]), 'M_ac_c': array([424.00759,  -3.642  ]), 'M_ac_e': array([1.00794, 0.1125 ]), 'M_h_e': array([116.01206,  -2.7336 ]), 'M_acald_c': array([663.11022,  -3.46613]), 'M_etoh_c': array([663.11022,  -3.46613]), 'M_acald_e': array([44.02621,  0.2052 ]), 'M_accoa_c': array([95.96234, -2.1926 ]), 'M_coa_c': array([862.09487,  -4.784  ]), 'M_pyr_c': array([87.00877, -1.6747 ]), 'M_acon_C_c': array([189.00517,  -5.3967 ]), 'M_cit_c': array([18.01056, -0.8247 ]), 'M_actp_c': array([137.97291,  -1.6218 ]), 'M_adp_c': array([87.00877, -1.6747 ]), 'M_f6p_c': array([95.96234, -2.1926 ]), 'M_oaa_c': array([95.96234, -2.1926 ]), 'M_amp_c': array([345.04853,  -3.127  ]), 'M_e4p_c': array([95.96234, -2.1926 ]), 'M_gln__L_c': array([95.96234, -2.1926 ]), 'M_glu__L_c': array([95.96234, -2.1926 ]), 'M_nadph_c': array([95.96234, -2.1926 ]), 'M_pep_c': array([87.00877, -1.6747 ]), 'M_r5p_c': array([288.02573,  -5.1633 ]), 'M_succ_c': array([862.09487,  -4.784  ]), 'M_nh4_c': array([95.96234, -2.1926 ]), 'M_gln__L_e': array([95.96234, -2.1926 ]), 'M_h_c': array([728.57436,  15.01762]), 'M_co2_c': array([95.96234, -2.1926 ]), 'M_akg_c': array([862.09487,  -4.784  ]), 'M_co2_e': array([43.98983, -0.5835 ]), 'M_icit_c': array([116.01206,  -2.7336 ]), 'M_mal__L_c': array([87.00877, -1.6747 ]), 'M_glx_c': array([132.00697,  -3.7628 ]), 'M_dhap_c': array([167.98347,  -2.6085 ]), 'M_fdp_c': array([95.96234, -2.1926 ]), 'M_s7p_c': array([288.02573,  -5.1633 ]), 'M_etoh_e': array([1.00794, 0.1125 ]), 'M_for_c': array([44.9982, -1.6339]), 'M_for_e': array([1.00794, 0.1125 ]), 'M_fum_c': array([116.01206,  -2.7336 ]), 'M_q8_c': array([728.57436,  15.01762]), 'M_fum_e': array([1.00794, 0.1125 ]), 'M_xu5p__D_c': array([228.0046,  -3.8851]), 'M_glu__L_e': array([1.00794, 0.1125 ]), 'M_o2_c': array([726.55871,  14.4009 ]), 'M_q8h2_c': array([116.01206,  -2.7336 ]), 'M_h2o_e': array([18.01056, -0.8247 ]), 'M_akg_e': array([1.00794, 0.1125 ]), 'M_pi_e': array([95.96234, -2.1926 ]), 'M_pyr_e': array([87.00877, -1.6747 ]), 'M_succ_e': array([116.01206,  -2.7336 ]), 'M_lac__D_e': array([89.02442, -1.8829 ]), 'M_nadh_c': array([728.57436,  15.01762]), 'M_lac__D_c': array([87.00877, -1.6747 ]), 'M_mal__L_e': array([132.00697,  -3.7628 ]), 'M_nh4_e': array([18.03383,  0.3762 ]), 'M_o2_e': array([31.98983,  0.067  ]), 'M_fru_e': array([87.00877, -1.6747 ]), 'M_glc__D_e': array([87.00877, -1.6747 ]), 'M_ru5p__D_c': array([228.0046,  -3.8851]), 'M_succoa_c': array([862.09487,  -4.784  ])}

# %%
mass_molLogP =  [(1.00794,0.1125),
(1.00794,0.1125),
(663.11022,-3.466129999999994),
(170.99461,-4.447399999999999),
(805.09667,-3.2941999999999974),
(255.99952,-4.160199999999997),
(862.09487,-4.783999999999996),
(180.06339,-3.2213999999999987),
(132.00697,-3.7628),
(189.00517,-5.252599999999999),
(261.93016,-4.435499999999998),
(46.04186,-0.0014),
(43.98983,-0.5835),
(228.0046,-3.885099999999998),
(228.0046,-3.885099999999998),
(728.57436,15.017619999999964),
(144.00697,-3.1644999999999994),
(87.00877,-1.6747),
(726.55871,14.40089999999997),
(116.01206,-2.733599999999999),
(197.99404,-3.2476),
(59.01385,-1.2438),
(182.97111,-4.057499999999999),
(137.97291,-1.6218),
(502.96664,-4.156999999999997),
(146.06914,-0.2862299999999998),
(44.9982,-1.6339),
(424.00759,-3.6419999999999977),
(129.99132,-3.5546),
(740.05362,-5.208129999999997),
(72.99312,-2.0648),
(763.0861,-3.644099999999999),
(182.97111,-4.057499999999999),
(345.04853,-3.126999999999998),
(18.03383,0.3762),
(180.06339,-3.219799999999999),
(164.96055,-2.904699999999999),
(95.96234,-2.1926),
(89.02442,-1.8829),
(288.02573,-5.163299999999996),
(273.0028,-5.974799999999997),
(46.04186,-0.0014),
(31.98983,0.067),
(31.98983,0.067),
(44.02621,0.2052),
(113.99641,-2.9576),
(741.062,-4.61313),
(167.98347,-2.608499999999999),
(146.04588,-2.071599999999999),
(44.02621,0.2052),
(167.98347,-2.606899999999999),
(662.10185,-4.061129999999994),
(189.00517,-5.396699999999999),
(95.96234,-2.1926),
(18.01056,-0.8247)]

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

net2 = nx.DiGraph()

# set the physics layout of the network
data = pd.read_csv("Chemical_descriptors_e_coli_core_ranked_targets.csv")

sources = data["BiGG"]
targets = data['target']
coordinates = mass_molLogP


edge_data = zip(sources, targets, coordinates)

for e in edge_data:
    src = e[0]
    dst = e[1]
    c = e[2]

    net2.add_node(src, pos = c)
    net2.add_node(dst, pos = c)
    net2.add_edge(src, dst)


pos=nx.get_node_attributes(net2,'pos')
fig, ax = plt.subplots(figsize=(50,50))

# net2.remove_edges_from(nx.selfloop_edges(net2))

nx.draw(net2,pos, with_labels = True, node_size = 40, arrows = True, ax = ax)

#nx.draw_networkx_nodes(net2, pos, cmap=plt.get_cmap('jet'),node_color = "b", node_size = 500, ) 
#nx.draw_networkx_labels(net2, pos,font_size = 12, font_color="black")
#nx.draw_networkx_edges(net2, pos, edgelist=red_edges,  width=8, alpha=0.5, edge_color="tab:red", arrows = True)
#nx.draw_networkx_edges(net2, pos, edgelist=black_edges, arrows=True)
#nx.draw_networkx_edges(net2, pos, edgelist=blue_edges, arrows=True)
limits=plt.axis('on') # turns on axis
ax.set_xlabel("mass")
ax.set_ylabel("MolLogP")
ax.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True)
