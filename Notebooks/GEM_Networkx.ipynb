# %% [markdown]
# # set data dir

# %%
import sys
import os

# path = "C:/Users/meide/Documents/GitHub/Master/data"
path = "data/"
os.chdir(path)

# %%
import pandas as pd

df = pd.read_csv("PyvisData_BiGG_MNXM.csv")

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

net2 = nx.DiGraph()

# set the physics layout of the network
data = pd.read_csv("PyvisData_BiGG_MNXM.csv")

sources = data["BiGG"]
targets = data['target']
coordinates = MolLogP_NumHDonor

edge_data = zip(sources, coordinates)

for e in edge_data:
    src = e[0]
    c = e[1]
   

    net2.add_node(src, pos = c)
    # net2.add_node(dst, pos = c)
   

blue_edges = [("pep", "pyr")]
red_edges = [('pyr', 'accoa'),("accoa","cit"),("akg","succoa"),("succoa","succ")]
Green_edges = [('accoa', 'cit')]

edge_colours = ['black' if not edge in red_edges else 'tab:red'
                    for edge in net2.edges()]

black_edges = [edge for edge in net2.edges() if edge not in red_edges]

blue_edges = [edge for edge in net2.edges() if edge not in red_edges and black_edges]





pos=nx.get_node_attributes(net2,'pos')
fig, ax = plt.subplots(figsize=(50,40))

nx.draw(net2,pos, with_labels = False, arrows = True, ax = ax)

#nx.draw_networkx_nodes(net2, pos, cmap=plt.get_cmap('jet'),node_color = "b", node_size = 500, ) 
#nx.draw_networkx_labels(net2, pos,font_size = 12, font_color="black")
#nx.draw_networkx_edges(net2, pos, edgelist=red_edges,  width=8, alpha=0.5, edge_color="tab:red", arrows = True)
#nx.draw_networkx_edges(net2, pos, edgelist=black_edges, arrows=True)
#nx.draw_networkx_edges(net2, pos, edgelist=blue_edges, arrows=True)
limits=plt.axis('on') # turns on axis
ax.set_xlabel("ExactMolWt")
ax.set_ylabel("MolLogP")
ax.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True)

# %%
Charge_NumHDonors = [(1.0,0),
(-2.0,7),
(-3.0,0),
(0.0,0),
(-1.0,2),
(-1.0,0),
(-1.0,5),
(-1.0,1),
(-1.0,0),
(-1.0,0),
(-1.0,3),
(-2.0,6),
(-3.0,0),
(0.0,2),
(-4.0,5),
(-1.0,2),
(-1.0,0),
(0.0,2),
(-1.0,5),
(0.0,2),
(-4.0,5),
(-4.0,5),
(-2.0,0),
(1.0,1),
(-2.0,4),
(-1.0,6),
(-3.0,1),
(-2.0,7),
(0.0,4),
(-2.0,7),
(-1.0,21),
(-2.0,5),
(-3.0,2),
(-5.0,11),
(-4.0,3),
(-2.0,3),
(-2.0,4),
(-1.0,5),
(-3.0,5),
(0.0,3),
(-4.0,10),
(1.0,5),
(-3.0,3),
(-2.0,5),
(-4.0,4),
(0.0,5),
(-2.0,3),
(-2.0,7),
(-2.0,3),
(-3.0,4),
(0.0,3),
(-2.0,6),
(-2.0,3),
(0.0,4),
(-2.0,3),
(-3.0,5),
(-2.0,5),
(-2.0,4),
(0.0,3),
(0.0,10),
(2.0,4),
(0.0,4),
(-3.0,0),
(-2.0,5),
(0.0,6),
(-4.0,3),
(-2.0,1),
(-1.0,0),
(-4.0,2),
(-4.0,5),
(-3.0,3),
(-4.0,5),
# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

net2 = nx.DiGraph()

# set the physics layout of the network
data = pd.read_csv("Metabolic_network_targets.csv")

sources = data["BiGG"]
targets = data['target']
coordinates = Charge_NumHDonors


edge_data = zip(sources, targets, coordinates)

for e in edge_data:
    src = e[0]
    dst = e[1]
    c = e[2]

    net2.add_node(src, pos = c)
    net2.add_node(dst, pos = c)
    net2.add_edge(src, dst)


pos=nx.get_node_attributes(net2,'pos')
fig, ax = plt.subplots(figsize=(10,10))

net2.remove_edges_from(nx.selfloop_edges(net2))

nx.draw(net2,pos, with_labels = False, node_size = 10, arrows = True, ax = ax)

#nx.draw_networkx_nodes(net2, pos, cmap=plt.get_cmap('jet'),node_color = "b", node_size = 500, ) 
#nx.draw_networkx_labels(net2, pos,font_size = 12, font_color="black")
#nx.draw_networkx_edges(net2, pos, edgelist=red_edges,  width=8, alpha=0.5, edge_color="tab:red", arrows = True)
#nx.draw_networkx_edges(net2, pos, edgelist=black_edges, arrows=True)
#nx.draw_networkx_edges(net2, pos, edgelist=blue_edges, arrows=True)
limits=plt.axis('on') # turns on axis
ax.set_xlabel("massRank")
ax.set_ylabel("MolLogPRank")
ax.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27592\904686041.py in <module>
#      30 net2.remove_edges_from(nx.selfloop_edges(net2))
#      31
# ---> 32 nx.draw(net2,pos, with_labels = False, node_size = 10, arrows = True, ax = ax)
#      33
#      34 #nx.draw_networkx_nodes(net2, pos, cmap=plt.get_cmap('jet'),node_color = "b", node_size = 500, )
#
# ~\.conda\envs\DrugDL\lib\site-packages\networkx\drawing\nx_pylab.py in draw(G, pos, ax, **kwds)
#     124
#     125     try:
# --> 126         draw_networkx(G, pos=pos, ax=ax, **kwds)
#     127         ax.set_axis_off()
#     128         plt.draw_if_interactive()
#
# ~\.conda\envs\DrugDL\lib\site-packages\networkx\drawing\nx_pylab.py in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     276
#     277     node_collection = draw_networkx_nodes(G, pos, **kwds)
# --> 278     edge_collection = draw_networkx_edges(G, pos, arrows=arrows, **kwds)
#     279     if with_labels:
#     280         draw_networkx_labels(G, pos, **kwds)
#
# ~\.conda\envs\DrugDL\lib\site-packages\networkx\drawing\nx_pylab.py in draw_networkx_edges(G, pos, edgelist, width, edge_color, style, alpha, arrowstyle, arrowsize, edge_cmap, edge_vmin, edge_vmax, ax, arrows, label, node_size, nodelist, node_shape, **kwds)
#     561     edge_pos = np.asarray([(pos[e[0]], pos[e[1]]) for e in edgelist])
#     562
# --> 563     if not cb.iterable(width):
#     564         lw = (width,)
#     565     else:
#
# AttributeError: module 'matplotlib.cbook' has no attribute 'iterable'

# %%
nx.info(net2)
# Out:
# 'DiGraph with 512 nodes and 722 edges'

# %%
nx.degree_histogram(net2)
