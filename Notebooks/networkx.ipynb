# %% [markdown]
# #### Set data dir

# %%
import sys
import os

# path = "C:/Users/meide/Documents/GitHub/Master/data"
path = "data/"
os.chdir(path)

# %%
import pandas as pd
import networkx as nx

# %%
df = pd.read_csv("TCA_PCA_standardized.csv")

# %%
df1 = df[["BiGG", "target", "PC1", "PC2"]]

lol = df1.to_dict()
BiGG = df1["BiGG"].to_list()
target = df1["target"].to_list()
PC1 = df1["PC1"].to_list()
PC2 = df1["PC2"].to_list()

# %%
lol2 = df.to_dict()
lol = df1.to_dict()
print(lol)
# Out:
# {'BiGG': {0: 'accoa', 1: 'succoa', 2: 'cit', 3: 'mal__D', 4: 'akg', 5: 'pyr', 6: 'succ', 7: 'oaa', 8: 'pep', 9: 'fum', 10: 'icit'}, 'target': {0: 'cit', 1: 'succ', 2: 'icit', 3: 'oaa', 4: 'succoa', 5: 'accoa', 6: 'fum', 7: 'cit', 8: 'pyr', 9: 'mal__D', 10: 'akg'}, 'PC1': {0: 3.5529909496208143, 1: 4.136093289012364, 2: -2.900509379333349, 3: -3.569842822597604, 4: -3.373730530173366, 5: -4.092546108593954, 6: -3.758400925264014, 7: -3.5143510602619465, 8: -3.010374247593208, 9: -3.894409131149954, 10: -2.889970107370852}, 'PC2': {0: -1.0712422109687498, 1: -0.9637666376336744, 2: -1.1856010904528047, 3: -0.545456600478687, 4: -0.4032410571842423, 5: -0.0495345431247979, 6: -0.265575596780281, 7: -0.303275078814657, 8: -1.4057722742963084, 9: 0.171521899944883, 10: -0.9587023175376778}}

# %%
TCA_dict =dict(zip(BiGG,target))
print(TCA_dict)
# Out:
# {'accoa': 'cit', 'succoa': 'succ', 'cit': 'icit', 'mal__D': 'oaa', 'akg': 'succoa', 'pyr': 'accoa', 'succ': 'fum', 'oaa': 'cit', 'pep': 'pyr', 'fum': 'mal__D', 'icit': 'akg'}

# %%
len(BiGG)
# Out:
# 11

# %%
import networkx as nx

G = nx.DiGraph()

# %%
G = nx.from_pandas_edgelist(df1, "BiGG", "target")
pos=nx.get_node_attributes(G,'pos')

# %%
pos
# Out:
# {}

# %%
from matplotlib.pyplot import figure

G.remove_edges_from(nx.selfloop_edges(G))

figure(figsize=(10,8))

nx.draw_networkx(G,pos, with_labels=True,node_size=1500, arrows = True)

# %%
G1 = nx.DiGraph()

# %%
nx.draw_networkx(G1,with_labels=True,node_size=1500)

# %%
TCA = nx.DiGraph()

# %%
TCA.add_nodes_from(TCA_dict)

# %%
nx.draw_networkx(TCA, with_labels = True, node_size = 1500, arrows = True)

# %%
pos = {0: (40, 20), 1: (20, 30), 2: (40, 30), 3: (30, 10)} 
X=nx.Graph()
nx.draw_networkx_nodes(X,pos,node_size=3000,nodelist=[0,1,2,3],node_color='r')

# %%
import networkx as nx

G=nx.DiGraph()

G.add_node("accoa",pos=(3.5529909496,-1.071242211))

G.add_node("cit",pos=(-2.9005093793,-1.1856010905))

G.add_edge("accoa","cit")


G.add_node("succoa",pos =(4.136093289,-0.9637666376))

G.add_node("succ", pos =(-3.7584009253,-0.2655755968))

G.add_edge("succoa", "succ")

G.add_node("mal__D", pos = (-3.5698428226,-0.5454566005)) 

G.add_node("oaa", pos = (-3.5143510603,-0.3032750788))

G.add_edge("mal__D", "oaa")

G.add_node("akg", pos =(-3.3737305302,-0.4032410572))
G.add_edge("akg", "succoa")

G.add_node("pyr", pos = (-4.0925461086,-0.0495345431 ))
G.add_edge("pyr", "accoa")


G.add_node("fum", pos =(-3.8944091311,0.1715218999))
G.add_edge("succ","fum")


G.add_node("pep", pos =(-3.0103742476,-1.4057722743))
G.add_edge("pep", "pyr")

G.add_node("icit", pos=(-2.8899701074,-0.9587023175 ))
G.add_edge("icit", "akg")


G.add_edge("cit", "icit")
pos=nx.get_node_attributes(G,'pos')

# pos

nx.draw(G, pos, with_labels = True, node_color = "skyblue", node_shape ="s", alpha = 0.5, arrows = True)

# %%
dfTCA = pd.read_csv("TCA_target_standardized.csv")

# %%
import networkx as nx

G=nx.DiGraph()

# NumValenceElectrons & Mass

G.add_node("accoa",pos=(0.5487169943009513,0.44456368131356905))#

G.add_node("cit",pos=(0.07328734380096749,0.295873590612898))# 

G.add_edge("accoa","cit")


G.add_node("succoa",pos =(0.6478338104,0.5414850326))#

G.add_node("succ", pos =(-0.6495641681,-0.6215711827))#

G.add_edge("succoa", "succ")

G.add_node("mal__D", pos = (-0.6217498699,-0.5951380868)) #

G.add_node("oaa", pos = (-0.6252549772,-0.6039491188)) #

G.add_edge("mal__D", "oaa")

G.add_node("akg", pos =(-0.6008825138,-0.577516023))# 
G.add_edge("akg", "succoa")

G.add_node("pyr", pos = (-0.6999993299020318,-0.6744373742516535 ))#
G.add_edge("pyr", "accoa")


G.add_node("fum", pos =(-0.6530692754,-0.6303822146))# 
G.add_edge("succ","fum")


G.add_node("pep", pos =(-0.5644453717,-0.568704991)) #
G.add_edge("pep", "pyr")

G.add_node("icit", pos=(-0.5226330537694392,-0.4982167356 ))#
G.add_edge("icit", "akg")


G.add_edge("cit", "icit")
pos=nx.get_node_attributes(G,'pos')

# pos

nx.draw(G, pos, with_labels = True, node_color = "skyblue", node_shape ="s", alpha = 0.5, arrows = True)

# %%
data = pd.read_csv("TCA_target_standardized.csv")

# PC1 = data.pop("PC1")
# PC2 = data.pop("PC2")

# %% [markdown]
# #

# %%
# NumValenceElectrons v MolLogP

Coordinates = [(-0.6744373743,-0.213616615), (0.4445636813,-0.5240855826),(-0.577516023,-0.4992212263),
(-0.6039491188,-0.574006002), (-0.6215711827, -0.416614818),(-0.568704991,-0.4494158309),(0.5414850326,-0.8096901939), (-0.6303822146,-0.4595571143),
 (-0.5951380868,-0.6139193327), (-0.4982167356,-0.8995239439), (-0.4982167356,-0.9271488764)]

# NumValenceElectrons v MolMR
= pd.read_csv("Chemical_descriptors_e_coli_core_ranked.csv")

sources = data["BiGG"]
#targets = data['target']
# coordinates = CoordinatesMolMR
coordinates = data[["ExactMolWt", "MolLogP"]].values

file_name = "BCUT2D_LOGPLOW__Morgan3"

edge_data = zip(sources, coordinates) # targets

for e in edge_data:
    src = e[0]
    #dst = e[1]
    c = e[1]

    net2.add_node(src, pos = c)
    #net2.add_node(dst, pos = c)
    #net2.add_edge(src, dst)

#blue_edges = [("pep", "pyr")]
#red_edges = [('pyr', 'accoa'),("accoa","cit"),("akg","succoa"),("succoa","succ")]
#Green_edges = [('accoa', 'cit')]

#edge_colours = ['black' if not edge in red_edges else 'tab:red'
                    #for edge in net2.edges()]

#black_edges = [edge for edge in net2.edges() if edge not in red_edges]

#blue_edges = [edge for edge in net2.edges() if edge not in red_edges and black_edges]





pos=nx.get_node_attributes(net2,'pos')
fig, ax = plt.subplots()

net2.remove_edges_from(nx.selfloop_edges(net2))

nx.draw(net2,pos, with_labels = True, arrows = True, ax = ax)

#nx.draw_networkx_nodes(net2, pos, cmap=plt.get_cmap('jet'),node_color = "b", node_size = 500, ) 
#nx.draw_networkx_labels(net2, pos,font_size = 12, font_color="black")
#nx.draw_networkx_edges(net2, pos, edgelist=red_edges,  width=8, alpha=0.5, edge_color="tab:red", arrows = True)
#nx.draw_networkx_edges(net2, pos, edgelist=black_edges, arrows=True)
#nx.draw_networkx_edges(net2, pos, edgelist=blue_edges, arrows=True)
limits=plt.axis('on') # turns on axis
ax.set_xlabel("NumValenceElectrons")
ax.set_ylabel("MolMR")
ax.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True)

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

net2 = nx.DiGraph()

# set the physics layout of the network
# data = pd.read_csv("TCA_target_standardized.csv")
data = pd.read_csv("Chemical_descriptors_e_coli_core_ranked.csv")
target = pd.read_csv("Chemical_descriptors_e_coli_core_ranked_targets.csv")

sources = data["BiGG"]
targets = target['target']
coordinates = data[["massRank", "MolLogPRank"]].values

file_name = "massRank_MolLogPRank"

edge_data = zip(sources,targets, coordinates) # targets

for e in edge_data:
    src = e[0]
    dst = e[1]
    c = e[2]

    net2.add_node(src, pos = c)
    net2.add_edge(src,dst)
    net2.add_edge(dst, src)
    
    
    #net2.add_node(dst, pos = c)
    #net2.add_edge(src, dst)






pos=nx.get_node_attributes(net2,'pos')
fig, ax = plt.subplots(figsize=(10,10))

net2.remove_edges_from(nx.selfloop_edges(net2))

nx.draw(net2,pos, with_labels = True, arrows = True, ax = ax)

limits=plt.axis('on') # turns on axis
ax.set_xlabel("massRank")
ax.set_ylabel("MolLogPRank")
ax.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True)

# %%
nx.info(net2)
# Out:
# 'DiGraph with 51 nodes and 102 edges'

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

net2 = nx.DiGraph()


#### 🐲GEM data🐲 ####

#  🦣  iML1515   🦣  #
# data = pd.read_csv("Chemical_descriptors1515_ranked.csv")
# target = pd.read_csv("iML1515_Metabolic_network_targets.csv")
#  🦣  iML1515   🦣   #


#  😈  E coli core   😈  #
# data = pd.read_csv("Chemical_descriptors_e_coli_core_ranked.csv")
# target  = pd.read_csv("Chemical_descriptors_e_coli_core_ranked_targets.csv")
#  😈  E coli core   😈  #

### 🐲GEM data🐲 ####

# 🗺️Pathways🗺️ #
    
####🍋 TCA data 🍋####

# charge_rank data not available for this model
# data = pd.read_csv("TCA_target_standardized_ranked.csv")
# target = pd.read_csv("TCA_target_standardized_ranked.csv")
# PCA  [PC1-PC5]
data = pd.read_csv("TCA_PCA_standardized.csv")
target = pd.read_csv("TCA_PCA_standardized.csv")
# PCA # 
####🍋 TCA data 🍋####



# 🗺️Pathways🗺️ #

sources = data["BiGG"]
targets = target['target']
coordinates = data[["PC1", "PC"]].values

file_name = "massRank_MolLogPRank"

edge_data = zip(sources,targets, coordinates) # targets

for e in edge_data:
    src = e[0]
    dst = e[1]
    c = e[2]

    net2.add_node(src, pos = c)
    net2.add_edge(src,dst)
    # net2.add_edge(dst, src)
    
    
    #net2.add_node(dst, pos = c)
    #net2.add_edge(src, dst)




print("PLUS ULTRA")

pos=nx.get_node_attributes(net2,'pos')
fig, ax = plt.subplots(figsize=(40,40))

net2.remove_edges_from(nx.selfloop_edges(net2))

nx.draw(net2,pos, with_labels = True, arrows = True, ax = ax)

limits=plt.axis('on') # turns on axis
ax.set_xlabel("massRank")
ax.set_ylabel("MolLogPRank")
ax.tick_params(left=True, bottom=True, labelleft=True, labelbottom=True)
# Out:
# PLUS ULTRA

# %%
nx.info(net2)
# Out:
# C:\Users\meide\AppData\Local\Temp\ipykernel_24712\3281343343.py:1: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   nx.info(net2)
# 'DiGraph with 11 nodes and 22 edges'
