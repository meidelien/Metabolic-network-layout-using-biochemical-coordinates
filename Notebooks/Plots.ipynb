# %% [markdown]
# # ╰(*°▽°*)╯ Import stuff ╰(*°▽°*)╯

# %%
import pandas as pd
import rdkit as rdkit
from rdkit import Chem
from rdkit.Chem import AllChem, Descriptors
from rdkit.Chem import rdMolDescriptors
from rdkit import *
from rdkit.Chem import PandasTools
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import statsmodels.api as sm
import plotly.graph_objects as go
import plotly_express as px

# %%
df  = pd.read_csv("chemical_descriptors.csv")

# %% [markdown]
# # Plot of MolLogP vs Fingerprint Density Morgan 3

# %%
df.plot(kind="scatter", x="MolLogP", y = "FpDensityMorgan3", color="red")
# Out:
# <AxesSubplot:xlabel='MolLogP', ylabel='FpDensityMorgan3'>

# %%
df.plot(kind="scatter", x="MolLogP", y = "FpDensityMorgan3", color="red")

# %%
df.plot(kind="scatter", x = "ExactMolWt", y  = "FpDensityMorgan3", color = "red")
# Out:
# <AxesSubplot:xlabel='ExactMolWt', ylabel='FpDensityMorgan3'>

# %%
df.plot(kind="scatter", x = "ExactMolWt", y  = "MolLogP", color = "red")
plt.savefig("ExactMolWt_MolLogP.png", transparent = True)
plt.savefig('ExactMolWt_MolLogLOL',  bbox_inches='tight')

# %%
df.plot(kind="scatter", x = "MaxPartialCharge", y  = "FpDensityMorgan3", color = "red")
# Out:
# <AxesSubplot:xlabel='MaxPartialCharge', ylabel='FpDensityMorgan3'>

# %%
df.plot(kind="scatter", x = "MaxPartialCharge", y  = "MolLogP", color = "red")
# Out:
# <AxesSubplot:xlabel='MaxPartialCharge', ylabel='MolLogP'>

# %%
df.plot(kind="scatter", x = "MinPartialCharge", y  = "FpDensityMorgan3", color = "red")
# Out:
# <AxesSubplot:xlabel='MinPartialCharge', ylabel='FpDensityMorgan3'>

# %%
df.plot(kind="scatter", x = "MaxPartialCharge", y  = "FpDensityMorgan1", color = "red")
# Out:
# <AxesSubplot:xlabel='MaxPartialCharge', ylabel='FpDensityMorgan1'>

# %%
df.plot(kind="scatter", x = "MaxPartialCharge", y  = "FpDensityMorgan2", color = "red")
# Out:
# <AxesSubplot:xlabel='MaxPartialCharge', ylabel='FpDensityMorgan2'>

# %%
df.plot(kind="scatter", x = "MaxPartialCharge", y  = "FpDensityMorgan3", color = "red")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27272/203754396.py in <module>
# ----> 1 df.plot(kind="scatter", x = "MaxPartialCharge", y  = "FpDensityMorgan3", color = "red")
#
# NameError: name 'df' is not defined

# %%
df = pd.DataFrame({"A": [0,1]})
trend = regression.predict(beta=regression.beta, x=x[20:])
ax = df.plot()
ax.legend(loc='best', fancybox=True, framealpha=0)
ax.plot()
# Out:
# []

# %%
import statsmodels.api as sm

# %%
fig, ax = plt.subplots()
df.plot(kind= "scatter", x="MolLogP", y = "ExactMolWt", ax=ax)
# Out:
# <AxesSubplot:xlabel='MolLogP', ylabel='ExactMolWt'>

# %%
fig, ax = plt.subplots()
df.plot(kind= "scatter", x="MolLogP", y = "ExactMolWt", ax=ax)
model = sm.formula.ols(formula="MolLogP ~ ExactMolWt", data=df)
res = model.fit()
df.assign(fit=res.fittedvalues).plot(x="MolLogP", y="MolLogP", ax=ax)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\.conda\envs\my-rdkit-env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\.conda\envs\my-rdkit-env\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\.conda\envs\my-rdkit-env\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MolLogP'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
fig = go.Figure()
fig.add_trace(
    go.Scatter(
        x = df["MolLogP"],
        y = df["ExactMolWt"],
        fill = "tozeroy"
       
))

# %%
df.plot(kind="scatter", x = "MolLogP", y  = "NumValenceElectrons", color = "red")
# Out:
# <AxesSubplot:xlabel='MolLogP', ylabel='NumValenceElectrons'>

# %% [markdown]
# # Plot of the partition coefficient vs charge
# - Outliers are ubiquinone (MolLogP = 15 & Charge = 0)

# %%
df.plot(kind="scatter", x = "MolLogP", y  = "charge", color = "red")
# Out:
# <AxesSubplot:xlabel='MolLogP', ylabel='charge'>

# %%
df.plot(kind="scatter", x = "FpDensityMorgan1", y  = "charge", color = "red")
# Out:
# <AxesSubplot:xlabel='FpDensityMorgan1', ylabel='charge'>

# %%
df.plot(kind="scatter", x = "FpDensityMorgan2", y  = "charge", color = "red")
# Out:
# <AxesSubplot:xlabel='FpDensityMorgan2', ylabel='charge'>

# %%
df.plot(kind="scatter", x = "FpDensityMorgan3", y  = "charge", color = "red")
# Out:
# <AxesSubplot:xlabel='FpDensityMorgan3', ylabel='charge'>

# %%
df.plot(kind="scatter", x = "MinPartialCharge", y  = "charge", color = "red")
# Out:
# <AxesSubplot:xlabel='MinPartialCharge', ylabel='charge'>

# %%
df.plot(kind="scatter", x = "MaxPartialCharge", y  = "charge", color = "red")
# Out:
# <AxesSubplot:xlabel='MaxPartialCharge', ylabel='charge'>

# %%
df.plot(kind="scatter", x = "NumValenceElectrons", y  = "MolLogP", color = "red")
# Out:
# <AxesSubplot:xlabel='NumValenceElectrons', ylabel='MolLogP'>

# %%
df.plot(kind="scatter", x = "FpDensityMorgan3", y  = "ExactMolWt", color = "red")
# Out:
# <AxesSubplot:xlabel='FpDensityMorgan3', ylabel='ExactMolWt'>

# %%
df.plot(kind="scatter", x = "FpDensityMorgan3", y  = "HeavyAtomMolWt", color = "red")
# Out:
# <AxesSubplot:xlabel='FpDensityMorgan3', ylabel='HeavyAtomMolWt'>

# %%
df.plot(kind="scatter", x = "FpDensityMorgan3", y  = "NumAromaticHeterocycles", color = "red")
# Out:
# <AxesSubplot:xlabel='FpDensityMorgan3', ylabel='NumAromaticHeterocycles'>

# %%
df.plot(kind="scatter", x = "FpDensityMorgan3", y  = "NumAromaticRings", color = "red")
# Out:
# <AxesSubplot:xlabel='FpDensityMorgan3', ylabel='NumAromaticRings'>

# %%
df.plot(kind="scatter", x = "FpDensityMorgan3", y  = "NumRotatableBonds", color = "red")
# Out:
# <AxesSubplot:xlabel='FpDensityMorgan3', ylabel='NumRotatableBonds'>

# %%
df.plot(kind="scatter", x = "ExactMolWt", y  = "FpDensityMorgan1", color = "red")
# Out:
# <AxesSubplot:xlabel='ExactMolWt', ylabel='FpDensityMorgan1'>

# %%
df.plot(kind="scatter", x = "ExactMolWt", y  = "FpDensityMorgan2", color = "red")
# Out:
# <AxesSubplot:xlabel='ExactMolWt', ylabel='FpDensityMorgan2'>

# %%
df.plot(kind="scatter", x = "MolMR", y  = "FpDensityMorgan1", color = "red")
# Out:
# <AxesSubplot:xlabel='MolMR', ylabel='FpDensityMorgan1'>

# %%
df.plot(kind="scatter", x = "MolMR", y  = "FpDensityMorgan2", color = "red")
# Out:
# <AxesSubplot:xlabel='MolMR', ylabel='FpDensityMorgan2'>

# %%
df.plot(kind="scatter", x = "MolMR", y  = "FpDensityMorgan3", color = "red")
# Out:
# <AxesSubplot:xlabel='MolMR', ylabel='FpDensityMorgan3'>

# %%
df.plot(kind="scatter", x = "TPSA", y  = "FpDensityMorgan3", color = "red")
# Out:
# <AxesSubplot:xlabel='TPSA', ylabel='FpDensityMorgan3'>

# %%
df.plot(kind="scatter", x = "TPSA", y  = "FpDensityMorgan1", color = "red")
# Out:
# <AxesSubplot:xlabel='TPSA', ylabel='FpDensityMorgan1'>
