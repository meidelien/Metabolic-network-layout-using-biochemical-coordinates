# %% [markdown]
# # Set data dir

# %%
import sys
import os

# path = "C:/Users/meide/Documents/GitHub/Master/data"
path = "data/"
os.chdir(path)

# %% [markdown]
# # Use this for visualization 👌👌🦄🦄

# %%
import pandas as pd
from pyvis.network import Network
import os

import os
if not os.path.exists('./Pyvis_Stuff'):
    os.makedirs('./Pyvis_Stuff')

data = pd.read_csv("TCA.csv") 
g = Network(height='900px', width='100%')

featurex = "PC2"
featurey = "PC3"

g.add_nodes(data["BiGG"], 
            title = data["MNXM"],
            x = data[featurex],
            y= data[featurey],
            label = data["BiGG"],                        
)
g.show("hey.html")
# g.show(f"./Pyvis_Stuff/{featurex}_{featurey}HALLO.html")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\meide\.conda\envs\rdkit\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/meide/.conda/envs/rdkit/lib/site-packages/pandas/core/indexes/base.py?line=3619'>3620</a> try:
# -> <a href='file:///c%3A/Users/meide/.conda/envs/rdkit/lib/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Users/meide/.conda/envs/rdkit/lib/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
#
# File c:\Users\meide\.conda\envs\rdkit\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\meide\.conda\envs\rdkit\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PC2'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\GitHub\Metabolic-network-layout-using-biochemical-coordinates\Archive\Pyvis.ipynb Cell 4' in <cell line: 15>()
#      <a href='vscode-notebook-cell:/c%3A/GitHub/Metabolic-network-layout-using-biochemical-coordinates/Archive/Pyvis.ipynb#ch0000003?line=11'>12</a> featurex = "PC2"
#      <a href='vscode-notebook-cell:/c%3A/GitHub/Metabolic-network-layout-using-biochemical-coordinates/Archive/Pyvis.ipynb#ch0000003?line=12'>13</a> featurey = "PC3"
#      <a href='vscode-notebook-cell:/c%3A/GitHub/Metabolic-network-layout-using-biochemical-coordinates/Archive/Pyvis.ipynb#ch0000003?line=14'>15</a> g.add_nodes(data["BiGG"],
#      <a href='vscode-notebook-cell:/c%3A/GitHub/Metabolic-network-layout-using-biochemical-coordinates/Archive/Pyvis.ipynb#ch0000003?line=15'>16</a>             title = data["MNXM"],
# ---> <a href='vscode-notebook-cell:/c%3A/GitHub/Metabolic-network-layout-using-biochemical-coordinates/Archive/Pyvis.ipynb#ch0000003?line=16'>17</a>             x = data[featurex],
#      <a href='vscode-notebook-cell:/c%3A/GitHub/Metabolic-network-layout-using-biochemical-coordinates/Archive/Pyvis.ipynb#ch0000003?line=17'>18</a>             y= data[featurey],
#      <a href='vscode-notebook-cell:/c%3A/GitHub/Metabolic-network-layout-using-biochemical-coordinates/Archive/Pyvis.ipynb#ch0000003?line=18'>19</a>             label = data["BiGG"],
#      <a href='vscode-notebook-cell:/c%3A/GitHub/Metabolic-network-layout-using-biochemical-coordinates/Archive/Pyvis.ipynb#ch0000003?line=19'>20</a> )
#      <a href='vscode-notebook-cell:/c%3A/GitHub/Metabolic-network-layout-using-biochemical-coordinates/Archive/Pyvis.ipynb#ch0000003?line=20'>21</a> g.show("hey.html")
#
# File c:\Users\meide\.conda\envs\rdkit\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    <a href='file:///c%3A/Users/meide/.conda/envs/rdkit/lib/site-packages/pandas/core/frame.py?line=3502'>3503</a> if self.columns.nlevels > 1:
#    <a href='file:///c%3A/Users/meide/.conda/envs/rdkit/lib/site-packages/pandas/core/frame.py?line=3503'>3504</a>     return self._getitem_multilevel(key)
# -> <a href='file:///c%3A/Users/meide/.conda/envs/rdkit/lib/site-packages/pandas/core/frame.py?line=3504'>3505</a> indexer = self.columns.get_loc(key)
#    <a href='file:///c%3A/Users/meide/.conda/envs/rdkit/lib/site-packages/pandas/core/frame.py?line=3505'>3506</a> if is_integer(indexer):
#    <a href='file:///c%3A/Users/meide/.conda/envs/rdkit/lib/site-packages/pandas/core/frame.py?line=3506'>3507</a>     indexer = [indexer]
#
# File c:\Users\meide\.conda\envs\rdkit\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/meide/.conda/envs/rdkit/lib/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Users/meide/.conda/envs/rdkit/lib/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
# -> <a href='file:///c%3A/Users/meide/.conda/envs/rdkit/lib/site-packages/pandas/core/indexes/base.py?line=3622'>3623</a>     raise KeyError(key) from err
#    <a href='file:///c%3A/Users/meide/.conda/envs/rdkit/lib/site-packages/pandas/core/indexes/base.py?line=3623'>3624</a> except TypeError:
#    <a href='file:///c%3A/Users/meide/.conda/envs/rdkit/lib/site-packages/pandas/core/indexes/base.py?line=3624'>3625</a>     # If we have a listlike key, _check_indexing_error will raise
#    <a href='file:///c%3A/Users/meide/.conda/envs/rdkit/lib/site-packages/pandas/core/indexes/base.py?line=3625'>3626</a>     #  InvalidIndexError. Otherwise we fall through and re-raise
#    <a href='file:///c%3A/Users/meide/.conda/envs/rdkit/lib/site-packages/pandas/core/indexes/base.py?line=3626'>3627</a>     #  the TypeError.
#    <a href='file:///c%3A/Users/meide/.conda/envs/rdkit/lib/site-packages/pandas/core/indexes/base.py?line=3627'>3628</a>     self._check_indexing_error(key)
#
# KeyError: 'PC2'

# %% [markdown]
# # Extracting the TCA metabolites from the model

# %%
import pandas as pd

# File below can be raw computed features, PCA or standardized 
data = pd.read_csv("PCA_test.csv")

TCA_list =["pyr","accoa", "akg", "oaa", "succ", "pep", "succoa", "fum", "mal__D", "cit","icit"]

TCA_df = data[data["BiGG"].isin(TCA_list)]

TCA_targets = pd.read_csv("TCA_target.csv")

TCA_df.insert(9, "target",TCA_targets["target"])

TCA_df.to_csv("TCA_PCA.csv")
# print(y)

# %% [markdown]
# ### Pyvis TCA - PCA

# %%
from pyvis.network import Network
import pandas as pd

net2 = Network(height='750px', width='50%', bgcolor='#222222', font_color='white')

# set the physics layout of the network
net2.barnes_hut()
data = pd.read_csv("TCA.csv") # Make this file, ok :))))

sources = data["BiGG"]
targets = data["target"]
x_coordinates = data["PC1"]  # Feature x as x coordinates
y_coordinates = data["PC2"] # Feature y as y coordinates
#labels = data["MNXM"]
edge_data = zip(sources, targets, x_coordinates, y_coordinates)


featurex = "PC1"
featurey = "PC2"
for e in edge_data:
    src = e[0]
    dst = e[1]
    x_c = e[2]
    y_c = e[3]
    #labels = e[4]

    net2.add_node(src, src, x= x_c, y = y_c, title=src)
    net2.add_node(dst, dst, x = x_c, y = y_c, title=dst)
    net2.add_edge(src, dst)

neighbor_map = net2.get_adj_list()

# add neighbor data to node hover data
for node in net2.nodes:
    node['title'] += ' Neighbors:<br>' + '<br>'.join(neighbor_map[node['id']])
    node['value'] = len(neighbor_map[node['id']])

net2.show_buttons(filter_=['physics'])
net2.set_edge_smooth("dynamic")
net2.show('TCA_cycle.html')
# net2.show(f"./Pyvis_Stuff/TCA_cycle_PCA_{featurex}_{featurey}.html")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\meide\.conda\envs\rdkit\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/meide/.conda/envs/rdkit/lib/site-packages/pandas/core/indexes/base.py?line=3619'>3620</a> try:
# -> <a href='file:///c%3A/Users/meide/.conda/envs/rdkit/lib/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Users/meide/.conda/envs/rdkit/lib/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
#
# File c:\Users\meide\.conda\envs\rdkit\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\meide\.conda\envs\rdkit\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'target'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\GitHub\Metabolic-network-layout-using-biochemical-coordinates\Archive\Pyvis.ipynb Cell 8' in <cell line: 11>()
#       <a href='vscode-notebook-cell:/c%3A/GitHub/Metabolic-network-layout-using-biochemical-coordinates/Archive/Pyvis.ipynb#ch0000007?line=7'>8</a> data = pd.read_csv("TCA.csv") # Make this file, ok :))))
#      <a href='vscode-notebook-cell:/c%3A/GitHub/Metabolic-network-layout-using-biochemical-coordinates/Archive/Pyvis.ipynb#ch0000007?line=9'>10</a> sources = data["BiGG"]
# ---> <a href='vscode-notebook-cell:/c%3A/GitHub/Metabolic-network-layout-using-biochemical-coordinates/Archive/Pyvis.ipynb#ch0000007?line=10'>11</a> targets = data["target"]
#      <a href='vscode-notebook-cell:/c%3A/GitHub/Metabolic-network-layout-using-biochemical-coordinates/Archive/Pyvis.ipynb#ch0000007?line=11'>12</a> x_coordinates = data["PC1"]  # Feature x as x coordinates
#      <a href='vscode-notebook-cell:/c%3A/GitHub/Metabolic-network-layout-using-biochemical-coordinates/Archive/Pyvis.ipynb#ch0000007?line=12'>13</a> y_coordinates = data["PC2"] # Feature y as y coordinates
#
# File c:\Users\meide\.conda\envs\rdkit\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    <a href='file:///c%3A/Users/meide/.conda/envs/rdkit/lib/site-packages/pandas/core/frame.py?line=3502'>3503</a> if self.columns.nlevels > 1:
#    <a href='file:///c%3A/Users/meide/.conda/envs/rdkit/lib/site-packages/pandas/core/frame.py?line=3503'>3504</a>     return self._getitem_multilevel(key)
# -> <a href='file:///c%3A/Users/meide/.conda/envs/rdkit/lib/site-packages/pandas/core/frame.py?line=3504'>3505</a> indexer = self.columns.get_loc(key)
#    <a href='file:///c%3A/Users/meide/.conda/envs/rdkit/lib/site-packages/pandas/core/frame.py?line=3505'>3506</a> if is_integer(indexer):
#    <a href='file:///c%3A/Users/meide/.conda/envs/rdkit/lib/site-packages/pandas/core/frame.py?line=3506'>3507</a>     indexer = [indexer]
#
# File c:\Users\meide\.conda\envs\rdkit\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/meide/.conda/envs/rdkit/lib/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Users/meide/.conda/envs/rdkit/lib/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
# -> <a href='file:///c%3A/Users/meide/.conda/envs/rdkit/lib/site-packages/pandas/core/indexes/base.py?line=3622'>3623</a>     raise KeyError(key) from err
#    <a href='file:///c%3A/Users/meide/.conda/envs/rdkit/lib/site-packages/pandas/core/indexes/base.py?line=3623'>3624</a> except TypeError:
#    <a href='file:///c%3A/Users/meide/.conda/envs/rdkit/lib/site-packages/pandas/core/indexes/base.py?line=3624'>3625</a>     # If we have a listlike key, _check_indexing_error will raise
#    <a href='file:///c%3A/Users/meide/.conda/envs/rdkit/lib/site-packages/pandas/core/indexes/base.py?line=3625'>3626</a>     #  InvalidIndexError. Otherwise we fall through and re-raise
#    <a href='file:///c%3A/Users/meide/.conda/envs/rdkit/lib/site-packages/pandas/core/indexes/base.py?line=3626'>3627</a>     #  the TypeError.
#    <a href='file:///c%3A/Users/meide/.conda/envs/rdkit/lib/site-packages/pandas/core/indexes/base.py?line=3627'>3628</a>     self._check_indexing_error(key)
#
# KeyError: 'target'

# %% [markdown]
# ### TCA pyvis - not PCA

# %%
from pyvis.network import Network
import pandas as pd

net2 = Network(height='700px', width='70%', bgcolor='#222222', font_color='black', directed = True)

# set the physics layout of the network
net2.barnes_hut()
data = pd.read_csv("TCA_target_standardized.csv") # Make this file, ok :))))


sources = data["BiGG"]
targets = data['target']
x_coordinates = data["FpDensityMorgan1"]  # Feature x as x coordinates
y_coordinates = data["MolLogP"] # Feature y as y coordinates
edge_data = zip(sources, targets, x_coordinates, y_coordinates)

for e in edge_data:
    src = e[0]
    dst = e[1]
    x_c = e[2]
    y_c = e[3]

    net2.add_node(src, src, x= x_c, y = y_c,  title=src)
    net2.add_node(dst, dst, x = x_c, y = y_c, title=dst)
    net2.add_edge(src, dst)

neighbor_map = net2.get_adj_list()

# add neighbor data to node hover data
for node in net2.nodes:
    node['title'] += ' Neighbors:<br>' + '<br>'.join(neighbor_map[node['id']])
    node['value'] = len(neighbor_map[node['id']])

net2.show_buttons()
# net2.set_edge_smooth("dynamic")
net2.show(f"./Pyvis_Stuff/TCA_cycle_PCA_{featurex}_{featurey}_LOL.html")

# %%
from pyvis.network import Network
import pandas as pd

net2 = Network(height='700px', width='70%', bgcolor='#222222', font_color='black', directed = True)

# set the physics layout of the network
net2.barnes_hut()
data = pd.read_csv("AMP.csv") # Make this file, ok :))))


sources = data["BiGG"]
targets = data['target']
x_coordinates = data["FpDensityMorgan1"]  # Feature x as x coordinates
y_coordinates = data["MolLogP"] # Feature y as y coordinates
edge_data = zip(sources, targets, x_coordinates, y_coordinates)

for e in edge_data:
    src = e[0]
    dst = e[1]
    x_c = e[2]
    y_c = e[3]

    net2.add_node(src, src, x= x_c, y = y_c,  title=src)
    net2.add_node(dst, dst, x = x_c, y = y_c, title=dst)
    net2.add_edge(src, dst)

neighbor_map = net2.get_adj_list()

# add neighbor data to node hover data
for node in net2.nodes:
    node['title'] += ' Neighbors:<br>' + '<br>'.join(neighbor_map[node['id']])
    node['value'] = len(neighbor_map[node['id']])

net2.show_buttons()
# net2.set_edge_smooth("dynamic")
net2.show(f"./Pyvis_Stuff/AMP_{featurex}_{featurey}_LOL.html")

# %%
from pyvis.network import Network
import pandas as pd

net2 = Network(height='700px', width='70%', bgcolor='#222222', font_color='black', directed = True)

# set the physics layout of the network
net2.barnes_hut()
data = pd.read_csv("CTP.csv") # Make this file, ok :))))


sources = data["BiGG"]
targets = data['target']
x_coordinates = data["FpDensityMorgan1"]  # Feature x as x coordinates
y_coordinates = data["MolLogP"] # Feature y as y coordinates
edge_data = zip(sources, targets, x_coordinates, y_coordinates)

for e in edge_data:
    src = e[0]
    dst = e[1]
    x_c = e[2]
    y_c = e[3]

    net2.add_node(src, src, x= x_c, y = y_c,  title=src)
    net2.add_node(dst, dst, x = x_c, y = y_c, title=dst)
    net2.add_edge(src, dst)

neighbor_map = net2.get_adj_list()

# add neighbor data to node hover data
for node in net2.nodes:
    node['title'] += ' Neighbors:<br>' + '<br>'.join(neighbor_map[node['id']])
    node['value'] = len(neighbor_map[node['id']])

net2.show_buttons()
# net2.set_edge_smooth("dynamic")
net2.show(f"./Pyvis_Stuff/CTP_{featurex}_{featurey}_LOL.html")

# %%
from pyvis.network import Network
import pandas as pd

net2 = Network(height='700px', width='70%', bgcolor='#222222', font_color='black', directed = True)

# set the physics layout of the network
net2.barnes_hut()
data = pd.read_csv("GTP.csv") # Make this file, ok :))))


sources = data["BiGG"]
targets = data['target']
x_coordinates = data["FpDensityMorgan1"]  # Feature x as x coordinates
y_coordinates = data["MolLogP"] # Feature y as y coordinates
edge_data = zip(sources, targets, x_coordinates, y_coordinates)

for e in edge_data:
    src = e[0]
    dst = e[1]
    x_c = e[2]
    y_c = e[3]

    net2.add_node(src, src, x= x_c, y = y_c,  title=src)
    net2.add_node(dst, dst, x = x_c, y = y_c, title=dst)
    net2.add_edge(src, dst)

neighbor_map = net2.get_adj_list()

# add neighbor data to node hover data
for node in net2.nodes:
    node['title'] += ' Neighbors:<br>' + '<br>'.join(neighbor_map[node['id']])
    node['value'] = len(neighbor_map[node['id']])

net2.show_buttons()
# net2.set_edge_smooth("dynamic")
net2.show(f"./Pyvis_Stuff/GTP_{featurex}_{featurey}_LOL.html")

# %%
from pyvis.network import Network
import pandas as pd

net2 = Network(height='700px', width='70%', bgcolor='#222222', font_color='black', directed = True)

# set the physics layout of the network
net2.barnes_hut()
data = pd.read_csv("Histidine.csv") # Make this file, ok :))))


sources = data["BiGG"]
targets = data['target']
x_coordinates = data["FpDensityMorgan1"]  # Feature x as x coordinates
y_coordinates = data["MolLogP"] # Feature y as y coordinates
edge_data = zip(sources, targets, x_coordinates, y_coordinates)

for e in edge_data:
    src = e[0]
    dst = e[1]
    x_c = e[2]
    y_c = e[3]

    net2.add_node(src, src, x= x_c, y = y_c,  title=src)
    net2.add_node(dst, dst, x = x_c, y = y_c, title=dst)
    net2.add_edge(src, dst)

neighbor_map = net2.get_adj_list()

# add neighbor data to node hover data
for node in net2.nodes:
    node['title'] += ' Neighbors:<br>' + '<br>'.join(neighbor_map[node['id']])
    node['value'] = len(neighbor_map[node['id']])

net2.show_buttons()
# net2.set_edge_smooth("dynamic")
net2.show(f"./Pyvis_Stuff/Histidine_{featurex}_{featurey}_LOL.html")
